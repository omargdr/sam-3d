# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## 1. Imports and Model Loading

# %%
import time

t0 = time.time(); import torch; print("torch ok", time.time()-t0)
t0 = time.time(); import torchvision; print("torchvision ok", time.time()-t0)
t0 = time.time(); import detectron2; print("detectron2 ok", time.time()-t0)

t0 = time.time()
from utils import setup_sam_3d_body, setup_visualizer
print("utils ok", time.time()-t0)
# Out:
# torch ok 4.559983015060425
# torchvision ok 3.7312192916870117
# detectron2 ok 0.15854668617248535
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 t0 = time.time(); import detectron2; print("detectron2 ok", time.time()-t0)
#       7 t0 = time.time()
# ----> 8 from utils import setup_sam_3d_body, setup_visualizer
#       9 print("utils ok", time.time()-t0)
#
# File c:\Users\omarg\Documents\SAM\sam-3d-body\notebook\utils.py:13
#      10 import numpy as np
#      11 import torch
# ---> 13 from sam_3d_body import load_sam_3d_body_hf, SAM3DBodyEstimator
#      14 from sam_3d_body.metadata.mhr70 import pose_info as mhr70_pose_info
#      15 from sam_3d_body.visualization.renderer import Renderer
#
# ModuleNotFoundError: No module named 'sam_3d_body'

# %%
import sys
import os

parent_dir = os.path.dirname(os.getcwd()) 
sys.path.insert(0, parent_dir)

from utils import (
    setup_sam_3d_body, setup_visualizer, 
    visualize_2d_results, visualize_3d_mesh, save_mesh_results, 
    display_results_grid, process_image_with_mask
)

# Set up SAM 3D Body estimator
estimator = setup_sam_3d_body(hf_repo_id="facebook/sam-3d-body-vith")
# Set up visualizer
visualizer = setup_visualizer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       4 parent_dir = os.path.dirname(os.getcwd())
#       5 sys.path.insert(0, parent_dir)
# ----> 7 from utils import (
#       8     setup_sam_3d_body, setup_visualizer,
#       9     visualize_2d_results, visualize_3d_mesh, save_mesh_results,
#      10     display_results_grid, process_image_with_mask
#      11 )
#      13 # Set up SAM 3D Body estimator
#      14 estimator = setup_sam_3d_body(hf_repo_id="facebook/sam-3d-body-vith")
#
# File c:\Users\omarg\Documents\SAM\sam-3d-body\notebook\utils.py:11
#       9 import matplotlib.pyplot as plt
#      10 import numpy as np
# ---> 11 import torch
#      13 from sam_3d_body import load_sam_3d_body_hf, SAM3DBodyEstimator
#      14 from sam_3d_body.metadata.mhr70 import pose_info as mhr70_pose_info
#
# File c:\Users\omarg\anaconda3\envs\sam_3d_body\Lib\site-packages\torch\__init__.py:2247
#    2231 ################################################################################
#    2232 # Import most common subpackages
#    2233 ################################################################################
#    (...)   2238
#    2239 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2240 from torch.autograd import (  # usort: skip
#    2241     enable_grad as enable_grad,
#    2242     inference_mode as inference_mode,
#    2243     no_grad as no_grad,
#    2244     set_grad_enabled as set_grad_enabled,
#    2245 )
# -> 2247 from torch import (
#    2248     __config__ as __config__,
#    2249     __future__ as __future__,
#    2250     _awaits as _awaits,
#    2251     accelerator as accelerator,
#    2252     autograd as autograd,
#    2253     backends as backends,
#    2254     cpu as cpu,
#    2255     cuda as cuda,
#    2256     distributed as distributed,
#    2257     distributions as distributions,
#    2258     fft as fft,
#    2259     futures as futures,
#    2260     hub as hub,
#    2261     jit as jit,
#    2262     linalg as linalg,
#    2263     mps as mps,
#    2264     mtia as mtia,
#    2265     multiprocessing as multiprocessing,
#    2266     nested as nested,
#    2267     nn as nn,
#    2268     optim as optim,
#    2269     overrides as overrides,
#    2270     profiler as profiler,
#    2271     sparse as sparse,
#    2272     special as special,
#    2273     testing as testing,
#    2274     types as types,
#    2275     utils as utils,
#    2276     version as version,
#    2277     xpu as xpu,
#    2278 )
#    2279 from torch.signal import windows as windows
#    2282 # Quantized, sparse, AO, etc. should be last to get imported, as nothing
#    2283 # is expected to depend on them.
#
# File c:\Users\omarg\anaconda3\envs\sam_3d_body\Lib\site-packages\torch\distributions\__init__.py:117
#     115 from .transforms import *  # noqa: F403
#     116 from .uniform import Uniform
# --> 117 from .von_mises import VonMises
#     118 from .weibull import Weibull
#     119 from .wishart import Wishart
#
# File c:\Users\omarg\anaconda3\envs\sam_3d_body\Lib\site-packages\torch\distributions\von_mises.py:6
#       3 from typing import Optional
#       5 import torch
# ----> 6 import torch.jit
#       7 from torch import Tensor
#       8 from torch.distributions import constraints
#
# File c:\Users\omarg\anaconda3\envs\sam_3d_body\Lib\site-packages\torch\jit\__init__.py:24
#       9 # These are imported so users can access them from the `torch.jit` module
#      10 from torch._jit_internal import (
#      11     _Await,
#      12     _drop,
#    (...)     22     unused,
#      23 )
# ---> 24 from torch.jit._async import fork, wait
#      25 from torch.jit._await import _awaitable, _awaitable_nowait, _awaitable_wait
#      26 from torch.jit._decomposition_utils import _register_decomposition
#
# File c:\Users\omarg\anaconda3\envs\sam_3d_body\Lib\site-packages\torch\jit\_async.py:14
#      12 import torch
#      13 from torch._jit_internal import Future
# ---> 14 from torch.jit._builtins import _register_builtin
#      15 from torch.utils import set_module
#      18 set_module(Future, "torch.jit")
#
# File c:\Users\omarg\anaconda3\envs\sam_3d_body\Lib\site-packages\torch\jit\_builtins.py:102
#      19 _builtin_table: Optional[dict[int, str]] = None
#      21 _modules_containing_builtins = (
#      22     torch,
#      23     torch._C._nn,
#    (...)     28     torch._C._special,  # type: ignore[attr-defined]
#      29 )
#      31 _builtin_ops = [
#      32     # Pairs of (function, op_name)
#      33     (_pair, "aten::_pair"),
#      34     (_quadruple, "aten::_quadruple"),
#      35     (_single, "aten::_single"),
#      36     (_triple, "aten::_triple"),
#      37     (_list_with_default, "aten::list_with_default"),
#      38     (OrderedDict, "aten::dict"),
#      39     (dict, "aten::dict"),
#      40     (cudnn.is_acceptable, "aten::cudnn_is_acceptable"),
#      41     (math.ceil, "aten::ceil"),
#      42     (math.copysign, "aten::copysign"),
#      43     (math.erf, "aten::erf"),
#      44     (math.erfc, "aten::erfc"),
#      45     (math.exp, "aten::exp"),
#      46     (math.expm1, "aten::expm1"),
#      47     (math.fabs, "aten::fabs"),
#      48     (math.floor, "aten::floor"),
#      49     (math.gamma, "aten::gamma"),
#      50     (math.lgamma, "aten::lgamma"),
#      51     (math.log, "aten::log"),
#      52     (math.log10, "aten::log10"),
#      53     (math.log1p, "aten::log1p"),
#      54     (math.pow, "aten::pow"),
#      55     (math.sqrt, "aten::sqrt"),
#      56     (math.isnan, "aten::isnan"),
#      57     (math.asinh, "aten::asinh"),
#      58     (math.atanh, "aten::atanh"),
#      59     (math.cosh, "aten::cosh"),
#      60     (math.sinh, "aten::sinh"),
#      61     (math.tanh, "aten::tanh"),
#      62     (math.acos, "aten::acos"),
#      63     (math.asin, "aten::asin"),
#      64     (math.atan, "aten::atan"),
#      65     (math.atan2, "aten::atan2"),
#      66     (math.cos, "aten::cos"),
#      67     (math.sin, "aten::sin"),
#      68     (math.tan, "aten::tan"),
#      69     (math.asinh, "aten::asinh"),
#      70     (math.atanh, "aten::atanh"),
#      71     (math.acosh, "aten::acosh"),
#      72     (math.fmod, "aten::fmod"),
#      73     (math.modf, "aten::modf"),
#      74     (math.factorial, "aten::factorial"),
#      75     (math.frexp, "aten::frexp"),
#      76     (math.isinf, "aten::isinf"),
#      77     (math.degrees, "aten::degrees"),
#      78     (math.radians, "aten::radians"),
#      79     (cmath.isnan, "aten::isnan"),
#      80     (cmath.isfinite, "aten::isfinite"),
#      81     (cmath.isinf, "aten::isinf"),
#      82     (cmath.phase, "aten::angle"),
#      83     (cmath.rect, "aten::polar"),
#      84     (cmath.log, "aten::log"),
#      85     (cmath.log10, "aten::log10"),
#      86     (cmath.sqrt, "aten::sqrt"),
#      87     (cmath.exp, "aten::exp"),
#      88     (cmath.sin, "aten::sin"),
#      89     (cmath.tan, "aten::tan"),
#      90     (cmath.cos, "aten::cos"),
#      91     (cmath.asin, "aten::asin"),
#      92     (cmath.acos, "aten::acos"),
#      93     (cmath.atan, "aten::atan"),
#      94     (cmath.sinh, "aten::sinh"),
#      95     (cmath.cosh, "aten::cosh"),
#      96     (cmath.tanh, "aten::tanh"),
#      97     (cmath.asinh, "aten::asinh"),
#      98     (cmath.acosh, "aten::acosh"),
#      99     (cmath.atanh, "aten::atanh"),
#     100     (math.ldexp, "aten::ldexp"),
#     101     (torch._assert, "aten::_assert"),
# --> 102     (torch.autograd.grad, "aten::grad"),
#     103     (torch.autograd.backward, "aten::backward"),
#     104     (torch._C._infer_size, "aten::_infer_size"),
#     105     (
#     106         torch.nn.functional._no_grad_embedding_renorm_,  # type: ignore[attr-defined]
#     107         "aten::_no_grad_embedding_renorm_",
#     108     ),
#     109     (torch.nn.functional.assert_int_or_pair, "aten::_assert_int_or_pair"),
#     110     (torch.nn.init._no_grad_fill_, "aten::_no_grad_fill_"),
#     111     (torch.nn.init._no_grad_normal_, "aten::_no_grad_normal_"),
#     112     (torch.nn.init._no_grad_uniform_, "aten::_no_grad_uniform_"),
#     113     (torch.nn.init._no_grad_zero_, "aten::_no_grad_zero_"),
#     114     (torch._C._get_tracing_state, "aten::_get_tracing_state"),
#     115     (torch._C._get_cpu_capability, "aten::_get_cpu_capability"),
#     116     (warnings.warn, "aten::warn"),
#     117     (torch._VF.stft, "aten::stft"),  # type: ignore[attr-defined]
#     118     (torch._VF.istft, "aten::istft"),  # type: ignore[attr-defined]
#     119     (torch._VF.cdist, "aten::cdist"),  # type: ignore[attr-defined]
#     120     (torch._VF.norm, "aten::norm"),  # type: ignore[attr-defined]
#     121     (torch._VF.unique_dim, "aten::unique_dim"),
#     122     (torch._VF.unique_consecutive, "aten::unique_consecutive"),  # type: ignore[attr-defined]
#     123     (torch._VF.nuclear_norm, "aten::nuclear_norm"),
#     124     (torch._VF.frobenius_norm, "aten::frobenius_norm"),
#     125     (torch._VF.tensordot, "aten::tensordot"),  # type: ignore[attr-defined]
#     126 ]
#     128 # ops in torch.functional are bound to torch
#     129 # in these cases, we want to resolve the function to their python implementation
#     130 # instead looking up a builtin "aten::" schema
#     133 def _gen_torch_functional_registered_ops():
#     134     # eventually ops should encompass all of torch/functional.py, (torch.functional.__all__)
#     135     # but we are currently only able to compile some of the functions. additionally,
#     136     # some functions directly map to their aten:: implementations.
#     137     # TODO: add support for more ops
#
# AttributeError: partially initialized module 'torch' has no attribute 'autograd' (most likely due to a circular import)

# %% [markdown]
# ## 2. Process Image and Get Outputs

# %%
import cv2
import matplotlib.pyplot as plt

# Load and process the image
image_path = "images/dancing.jpg"  # Relative to notebook folder
img_cv2 = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img_cv2, cv2.COLOR_BGR2RGB)

# Process the image with SAM 3D Body
print("Processing image with SAM 3D Body...")
outputs = estimator.process_one_image(image_path)

print(f"Number of people detected: {len(outputs)}")
print(f"Output keys for first person: {list(outputs[0].keys()) if outputs else 'No people detected'}")

# Display the original image
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis('off')
plt.title('Original Image')
plt.show()

# %% [markdown]
# ## 3. 2D Visualization - Keypoints and Bounding Boxes

# %%
# Visualize 2D results using utils
if outputs:
    vis_results = visualize_2d_results(img_cv2, outputs, visualizer)
    
    # Display results using grid function
    titles = [f'Person {i} - 2D Keypoints & BBox' for i in range(len(vis_results))]
    display_results_grid(vis_results, titles, figsize_per_image=(6, 6))
else:
    print("No people detected in the image")

# %% [markdown]
# ## 4. 3D Mesh Visualization - Overlay and Side View

# %%
if outputs:
    mesh_results = visualize_3d_mesh(img_cv2, outputs, estimator.faces)
    
    # Display results
    for i, combined_img in enumerate(mesh_results):
        combined_rgb = cv2.cvtColor(combined_img, cv2.COLOR_BGR2RGB)
        
        plt.figure(figsize=(20, 5))
        plt.imshow(combined_rgb)
        plt.title(f'Person {i}: Original | Mesh Overlay | Front View | Side View')
        plt.axis('off')
        plt.show()
else:
    print("No people detected for 3D mesh visualization")

# %% [markdown]
# ## 5. Save 3D Mesh Files and Results

# %%
if outputs:
    # Get image name without extension
    image_name = os.path.splitext(os.path.basename(image_path))[0]
    
    # Create output directory
    output_dir = f"output/{image_name}"

    # Save all results (PLY meshes, overlay images, bbox images)
    ply_files = save_mesh_results(img_cv2, outputs, estimator.faces, output_dir, image_name)
    
    print(f"\n=== Saved Results for {image_name} ===")
    print(f"Output directory: {output_dir}")
    print(f"Number of PLY files created: {len(ply_files)}")
    
else:
    print("No results to save - no people detected")

# %% [markdown]
# ## 6. Mask-Based Inference

# %%
# Load mask and run inference
mask_path = "images/dancing_mask.png"

if os.path.exists(mask_path):
    # Load and display the mask
    mask_img = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    plt.figure(figsize=(8, 6))
    plt.imshow(mask_img, cmap='gray')
    plt.title('External Mask')
    plt.axis('off')
    plt.show()
    
    # Process with external mask
    mask_outputs = process_image_with_mask(estimator, image_path, mask_path)
    
    # Visualize and save results
    if mask_outputs:
        mask_mesh_results = visualize_3d_mesh(img_cv2, mask_outputs, estimator.faces)
        
        for i, combined_img in enumerate(mask_mesh_results):
            combined_rgb = cv2.cvtColor(combined_img, cv2.COLOR_BGR2RGB)
            plt.figure(figsize=(20, 5))
            plt.imshow(combined_rgb)
            plt.title(f'Mask-Based Person {i}: Original | Mesh Overlay | Front View | Side View')
            plt.axis('off')
            plt.show()
            
        # Save results
        mask_output_dir = f"output/mask_based_{image_name}"
        mask_ply_files = save_mesh_results(img_cv2, mask_outputs, estimator.faces, mask_output_dir, f"mask_{image_name}")
        print(f"Saved mask-based results to: {mask_output_dir}")
    else:
        print("No people detected with mask-based approach")
        
else:
    print(f"Mask file not found: {mask_path}")
